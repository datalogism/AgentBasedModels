# %% [markdown]
# ## Markov chain Monte Carlo basics
#
# Source :
# - https://www.tweag.io/blog/2019-10-25-mcmc-intro1/

# %%
# %matplotlib notebook
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 6]
np.random.seed(42)

# %%
state_space = ("sunny", "cloudy", "rainy")

# %%
transition_matrix = np.array(((0.6, 0.3, 0.1),
                              (0.3, 0.4, 0.3),
                              (0.2, 0.3, 0.5)))

# %%
n_steps = 20000
states = [0]
for i in range(n_steps):
    states.append(np.random.choice((0, 1, 2), p=transition_matrix[states[-1]]))
states = np.array(states)

# %%
def despine(ax, spines=('top', 'left', 'right')):
    for spine in spines:
        ax.spines[spine].set_visible(False)

fig, ax = plt.subplots()
width = 1000
offsets = range(1, n_steps, 5)
for i, label in enumerate(state_space):
    ax.plot(offsets, [np.sum(states[:offset] == i) / offset
            for offset in offsets], label=label)
ax.set_xlabel("number of steps")
ax.set_ylabel("likelihood")
ax.legend(frameon=False)
despine(ax, ('top', 'right'))
plt.show()

# %% [markdown]
# ## Metropolis-Hasting

# %% [markdown]
# - Intuition : tirer une valeur candidate dans une loi de proposition qui dépend dans le cas général de la valeur précédante de l'algo MCMC.
# - Particularité : la valeur candidate doit passer une étape d'acceptation-rejet
# - On doit donnaitre la loi a posteriori à une constante multiplicative près
# - Nombreux choix de propositions qui déterminent la longueur de la chaine transitoire, l'autocorrelattion de la chaine, la convergence de celle-ci et sa stationarité
#
# Outils pour sampler des distribution de probabilité non-standard

# %%
def log_prob(x):
     return -0.5 * np.sum(x ** 2)

# %% [markdown]
# symetric proposal distribution :
# pick state $x$ and pick a proposal from uniform law between $x$-$step$/2 and $x$+$step$/2

# %%
def proposal(x, stepsize):
    return np.random.uniform(low=x - 0.5 * stepsize,
                             high=x + 0.5 * stepsize,
                             size=x.shape)

# %%
def p_acc_MH(x_new, x_old, log_prob):
    return min(1, np.exp(log_prob(x_new) - log_prob(x_old)))

# %%
def sample_MH(x_old, log_prob, stepsize):
    x_new = proposal(x_old, stepsize)
    # here we determine whether we accept the new state or not:
    # we draw a random number uniformly from [0,1] and compare
    # it with the acceptance probability
    accept = np.random.random() < p_acc_MH(x_new, x_old, log_prob)
    if accept:
        return accept, x_new
    else:
        return accept, x_old

# %%
def build_MH_chain(init, stepsize, n_total, log_prob):

    n_accepted = 0
    chain = [init]

    for _ in range(n_total):
        accept, state = sample_MH(chain[-1], log_prob, stepsize)
        chain.append(state)
        n_accepted += accept

    acceptance_rate = n_accepted / float(n_total)

    return chain, acceptance_rate

# %%
chain, acceptance_rate = build_MH_chain(np.array([2.0]), 3.0, 10000, log_prob)
chain = [state for state, in chain]
print("Acceptance rate: {:.3f}".format(acceptance_rate))
last_states = ", ".join("{:.5f}".format(state)
                        for state in chain[-10:])
print("Last ten states of chain: " + last_states)
# Out:
# Acceptance rate: 0.720
# Last ten states of chain: 1.05847, 1.59966, 0.14389, -1.13281, 0.24131, -0.77448, -0.59703, 0.67707, 1.47065, 1.27361

# %%
def plot_samples(chain, log_prob, ax, orientation='vertical', normalize=True,
                 xlims=(-5, 5), legend=True):
    from scipy.integrate import quad

    ax.hist(chain, bins=50, density=True, label="MCMC samples",
           orientation=orientation)
    # we numerically calculate the normalization constant of our PDF
    if normalize:
        Z, _ = quad(lambda x: np.exp(log_prob(x)), -np.inf, np.inf)
    else:
        Z = 1.0
    xses = np.linspace(xlims[0], xlims[1], 1000)
    yses = [np.exp(log_prob(x)) / Z for x in xses]
    if orientation == 'horizontal':
        (yses, xses) = (xses, yses)
    ax.plot(xses, yses, label="true distribution")
    if legend:
        ax.legend(frameon=False)

fig, ax = plt.subplots()
plot_samples(chain[500:], log_prob, ax)
despine(ax)
ax.set_yticks(())
plt.show()

# %%
def sample_and_display(init_state, stepsize, n_total, n_burnin, log_prob):
    chain, acceptance_rate = build_MH_chain(init_state, stepsize, n_total, log_prob)
    print("Acceptance rate: {:.3f}".format(acceptance_rate))
    fig, ax = plt.subplots()
    plot_samples([state for state, in chain[n_burnin:]], log_prob, ax)
    despine(ax)
    ax.set_yticks(())
    plt.show()

sample_and_display(np.array([2.0]), 30, 10000, 500, log_prob)
# Out:
# Acceptance rate: 0.104

# %%
sample_and_display(np.array([2.0]), 0.1, 10000, 500, log_prob)
# Out:
# Acceptance rate: 0.985

# %%
sample_and_display(np.array([2.0]), 0.1, 500000, 25000, log_prob)
# Out:
# Acceptance rate: 0.990

# %%
sample_and_display(np.array([0.0]), 0.01, 500, 25, log_prob)
# Out:
# Acceptance rate: 1.000

# %% [markdown]
# ### Test non sym distrib

# %%
fig, ax = plt.subplots(1, 1)
a=10
x = np.linspace(skewnorm.ppf(0.01, a),

                skewnorm.ppf(0.99, a), 100)

ax.plot(x, skewnorm.pdf(x, a),

       'r-', lw=5, alpha=0.6, label='skewnorm pdf')
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)

ax.legend(loc='best', frameon=False)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-b56697dd2da4> in <module>
#       8
#       9        'r-', lw=5, alpha=0.6, label='skewnorm pdf')
# ---> 10 ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
#      11
#      12 ax.legend(loc='best', frameon=False)
#
# NameError: name 'r' is not defined

# %%
from scipy.stats import skewnorm
def proposal2(x, stepsize):
    a=10
    print("stepsize",stepsize)
    print("old",x)
    r = skewnorm.rvs(x + stepsize, size=1000)
    return r
    print("low :",l)
    print("high :",h)
    
    #return np.linspace(skewnorm.ppf(l,h,x.size)

def sample_MH2(x_old, log_prob, stepsize):
    x_new = proposal2(x_old, stepsize)
    # here we determine whether we accept the new state or not:
    # we draw a random number uniformly from [0,1] and compare
    # it with the acceptance probability
    accept = np.random.random() < p_acc_MH(x_new, x_old, log_prob)
    if accept:
        return accept, x_new
    else:
        return accept, x_old
def build_MH_chain2(init, stepsize, n_total, log_prob):

    n_accepted = 0
    chain = [init]

    for _ in range(n_total):
        accept, state = sample_MH2(chain[-1], log_prob, stepsize)
        chain.append(state)
        n_accepted += accept

    acceptance_rate = n_accepted / float(n_total)

    return chain, acceptance_rate

# %%
chain, acceptance_rate = build_MH_chain2(np.array([2.0]), 0.5, 10000, log_prob)
chain = [state for state, in chain]
print("Acceptance rate: {:.3f}".format(acceptance_rate))
last_states = ", ".join("{:.5f}".format(state)
                        for state in chain[-10:])
print("Last ten states of chain: " + last_states)
# Out:
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# ...
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# stepsize 0.5
# old [2.]
# Acceptance rate: 0.000
# Last ten states of chain: 2.00000, 2.00000, 2.00000, 2.00000, 2.00000, 2.00000, 2.00000, 2.00000, 2.00000, 2.00000
